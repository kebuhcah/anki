# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

home_url = 'https://web.archive.org/web/20170319093420/http://www.uzbek-glossary.com/'

with urllib.request.urlopen(home_url) as response:
    html = response.read()
soup = BeautifulSoup(html, 'html.parser')

cat_url_map = [{'category': ul.parent.b.string, 
                'url': ul.a.attrs['href'].split('#')[0]} for ul in soup.body('ul', class_='domains')]

cat_url_map
# Out:
# [{'category': 'Basic Concepts', 'url': 'bc.htm'},
#  {'category': 'Space & Time', 'url': 'st.htm'},
#  {'category': 'Forces & Motion', 'url': 'fm.htm'},
#  {'category': 'Matter & Nature', 'url': 'mn.htm'},
#  {'category': 'Life & Humans', 'url': 'lh.htm'},
#  {'category': 'Perception & Cognition', 'url': 'pc.htm'},
#  {'category': 'Meaning & Spirit', 'url': 'ms.htm'},
#  {'category': 'Character & Emotions', 'url': 'ce.htm'},
#  {'category': 'Action & Modality', 'url': 'am.htm'},
#  {'category': 'Attitudes', 'url': 'at.htm'},
#  {'category': 'Communauty', 'url': 'cm.htm'},
#  {'category': 'Conflict & Justice', 'url': 'cj.htm'},
#  {'category': 'Work & Possession', 'url': 'wp.htm'},
#  {'category': 'Daily Life (I)', 'url': 'd1.htm'},
#  {'category': 'Daily Life (II)', 'url': 'd2.htm'},
#  {'category': 'Locutions', 'url': 'lo.htm'},
#  {'category': 'Proper Names', 'url': 'pn.htm'}]

# %%
def extractCardsFromUrl(cat_url = 'ms.htm'):
    with urllib.request.urlopen(home_url + cat_url) as response:
        html = response.read()
    cat_soup = BeautifulSoup(html, 'html.parser')

    cards = []
    current_card = {}
    in_example = False
    example_text = []

    for h2 in cat_soup.find_all('h2'):
        #print(h2.text)
        for tr in h2.find_next_sibling('table').find_all('tr'):
            for i, td in enumerate(tr.find_all('td')):
                # item name in column 0
                if i == 0:
                    if td.text.strip():
                        #print('ITEM', td.text)
                        item_attributes = {'item': td.text.strip(), 
                                           'item_bold': bool(td.b), 
                                           'domain': h2.text.strip()}

                # desc (and example!) in column 1
                if i == 1:
                    if td.attrs['class'][0] == 'top_ex':
                        in_example = True
                        example_text = []

                    if in_example:
                        #print('EXAMPLE', td.text)
                        example_text.append(td.text.strip())
                    else:
                        if td.text.strip():
                            if 'item' in current_card:
                                cards.append(current_card)
                            #print('DESC', td.text)
                            current_card = item_attributes.copy()
                            current_card['desc'] = td.text.strip()
                            current_card['desc_bold'] = bool(td.b)
                            current_card['meaning'] = []
                            current_card['example'] = []

                    if td.attrs['class'][0] in ['bot_ex', 'bot_bot_ex']:
                        in_example = False
                        current_card['example'] = example_text

                # meaning in column 2
                if i == 2:
                    if td.text.strip():
                        current_card['meaning'].append(td.text.strip())

    result = pd.DataFrame(cards)
    result['url'] = cat_url
    
    return result

# %%
pagesCards = []

for page in cat_url_map[:-2]:
    print(page['category'])
    pagesCards.append(extractCardsFromUrl(page['url']))
    
AllCards = pd.concat(pagesCards).reset_index(drop=True)

example_explode = AllCards.example.apply(pd.Series)
example_explode = example_explode[range(4)].rename(columns=lambda i: 'example_' + str(i+1))
AllCards = AllCards.join(example_explode)

AllCards.meaning = AllCards.meaning.apply(lambda x: ' | '.join(x))

AllCards
# Out:
# Basic Concepts
# Space & Time
# Forces & Motion
# Matter & Nature
# Life & Humans
# Perception & Cognition
# Meaning & Spirit
# Character & Emotions
# Action & Modality
# Attitudes
# Communauty
# Conflict & Justice
# Work & Possession
# Daily Life (I)
# Daily Life (II)

# %%
BoldCards = AllCards[AllCards.desc_bold]
BoldCards.sample(20)
# Out:
#              item  item_bold                  domain  \
# 11744         PUL       True                 Economy
# 7172    qiziqtir-       True                Emotions
# 1551         SOAT       True       Time and Duration
# 2707     bo'shat-       True              Properties
# 2165      yotqiz-       True                  Motion
# 116        CHUNKI       True  Entities and Existence
# 7877      G'AYRAT       True        Acts and Results
# 13293     ACHCHIQ       True                    Food
# 1035        TEKIS       True                   Shape
# 351      MURAKKAB       True      Category and Order
# 3830        SOQOL       True                    Body
# 4028      OLXO'RI       True                  Plants
# 6887      ishonch       True               Character
# 8504       tayan-       True                  Manner
# 12536    gilamcha       True       Objects and Tools
# 4588        KO'R-       True              Perception
# 1241          OST       True                Location
# 12909     KO'YLAK       True                Clothing
# 5251   mashg'ulot       True               Knowledge
# 7356     baxtiyor       True                Emotions
#
#                               desc  desc_bold  \
# 11744                            n       True
# 7172                           v.t       True
# 1551   ~ numX+dan numY minut o'tdi       True
# 2707                           v.t       True
# 2165                           v.t       True
# 116                           conj       True
# 7877                             n       True
# 13293                          adj       True
# 1035                            ad       True
# 351                            adj       True
# 3830                             n       True
# 4028                             n       True
# 6887                   n | NX+ga ~       True
# 8504               v.int | NX+ga ~       True
# 12536                            n       True
# 4588                   ko'rib qol-       True
# 1241          NX+ning ~+ida/dan/ga       True
# 12909                            n       True
# 5251                             n       True
# 7356                           adj       True
#
#                                          meaning  \
# 11744                                      money
# 7172                interest, attract, fascinate
# 1551                              it is Y past X
# 2707                                empty, clear
# 2165              lay down | lay out, spread out
# 116                                      because
# 7877                     energy, willpower, zeal
# 13293           bitter, hot, spicy, strong; sour
# 1035                           smooth(ly); level
# 351                         complex, complicated
# 3830                                       beard
# 4028                                        plum
# 6887   (positive) belief, confidence, faith in X
# 8504    lean on/against X | rely on X, rest on X
# 12536                          small carpet, rug
# 4588                                      notice
# 1241                                     under X
# 12909                       shirt, dress, blouse
# 5251          task, operation | studies; classes
# 7356     fortunate, lucky, happy (moment, event)
#
#                                                  example     url  \
# 11744  [Bu kitob necha pul turadi?, How much does thi...  wp.htm
# 7172                                                  []  ce.htm
# 1551                                                  []  st.htm
# 2707                                                  []  mn.htm
# 2165                                                  []  fm.htm
# 116    [Siz majlisga borishingiz kerak, chunki u yerd...  bc.htm
# 7877   [Uning g'ayrati bor odam., He is an energetic ...  am.htm
# 13293             [Qalampir achchiqdir., Pepper is hot.]  d2.htm
# 1035   [Bu qog'oz tekis., This paper is smooth., Bu y...  st.htm
# 351    [Bu murakkab ish., This is a complicated matter.]  bc.htm
# 3830                                                  []  lh.htm
# 4028                                                  []  lh.htm
# 6887   [Men ishonamanki, sen bizning senga bo'lgan is...  ce.htm
# 8504   [Hozirgi zamon diagnostikasi psixologiyadagi e...  am.htm
# 12536                                                 []  d1.htm
# 4588                                                  []  pc.htm
# 1241   [U suv ostidan chiqdi., He got out of the wate...  st.htm
# 12909                                                 []  d1.htm
# 5251   [U adabiyot mashg'ulotidan mamnuniyat his etad...  pc.htm
# 7356   [Bu mamlakatning aholisi baxtiyordir., The peo...  ce.htm
#
#                                                example_1  \
# 11744                         Bu kitob necha pul turadi?
# 7172                                                 NaN
# 1551                                                 NaN
# 2707                                                 NaN
# 2165                                                 NaN
# 116    Siz majlisga borishingiz kerak, chunki u yerda...
# 7877                            Uning g'ayrati bor odam.
# 13293                               Qalampir achchiqdir.
# 1035                                    Bu qog'oz tekis.
# 351                                     Bu murakkab ish.
# 3830                                                 NaN
# 4028                                                 NaN
# 6887   Men ishonamanki, sen bizning senga bo'lgan ish...
# 8504   Hozirgi zamon diagnostikasi psixologiyadagi en...
# 12536                                                NaN
# 4588                                                 NaN
# 1241                               U suv ostidan chiqdi.
# 12909                                                NaN
# 5251     U adabiyot mashg'ulotidan mamnuniyat his etadi.
# 7356                Bu mamlakatning aholisi baxtiyordir.
#
#                                                example_2  \
# 11744                      How much does this book cost?
# 7172                                                 NaN
# 1551                                                 NaN
# 2707                                                 NaN
# 2165                                                 NaN
# 116    You must go to the meeting because people are ...
# 7877                             He is an energetic man.
# 13293                                     Pepper is hot.
# 1035                               This paper is smooth.
# 351                        This is a complicated matter.
# 3830                                                 NaN
# 4028                                                 NaN
# 6887       I hope, you'll justify our confidence in you.
# 8504   Modern diagnostics rest on the latest knowledg...
# 12536                                                NaN
# 4588                                                 NaN
# 1241                            He got out of the water.
# 12909                                                NaN
# 5251   He finds satisfaction in pursuit with literature.
# 7356                The people of this country is lucky.
#
#                                               example_3  \
# 11744                                               NaN
# 7172                                                NaN
# 1551                                                NaN
# 2707                                                NaN
# 2165                                                NaN
# 116                                                 NaN
# 7877                                                NaN
# 13293                                               NaN
# 1035                                      Bu yer tekis.
# 351                                                 NaN
# 3830                                                NaN
# 4028                                                NaN
# 6887                                                NaN
# 8504                                                NaN
# 12536                                               NaN
# 4588                                                NaN
# 1241                  Uning qo'l ostida besh kishi bor.
# 12909                                               NaN
# 5251   Professor tarix bo'yicha mashg'ulot o'tkazyapti.
# 7356                                                NaN
#
#                                         example_4
# 11744                                         NaN
# 7172                                          NaN
# 1551                                          NaN
# 2707                                          NaN
# 2165                                          NaN
# 116                                           NaN
# 7877                                          NaN
# 13293                                         NaN
# 1035                         This place is level.
# 351                                           NaN
# 3830                                          NaN
# 4028                                          NaN
# 6887                                          NaN
# 8504                                          NaN
# 12536                                         NaN
# 4588                                          NaN
# 1241   There are five people under his direction.
# 12909                                         NaN
# 5251   The professor is giving a history lecture.
# 7356                                          NaN

# %%
# .to_csv('uzbek_bold.tsv',sep='\t', index=False)

BoldCards[['item', 'desc', 'domain', 'meaning'
           , 'example_1', 'example_2', 'example_3', 'example_4']].to_csv('uzbek_bold.tsv',sep='\t', index=True)
