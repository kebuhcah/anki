# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

home_url = 'https://web.archive.org/web/20170319093420/http://www.uzbek-glossary.com/'

with urllib.request.urlopen(home_url) as response:
    html = response.read()
soup = BeautifulSoup(html, 'html.parser')

cat_url_map = [{'category': ul.parent.b.string, 
                'url': ul.a.attrs['href'].split('#')[0]} for ul in soup.body('ul', class_='domains')]

cat_url_map
# Out:
# [{'category': 'Basic Concepts', 'url': 'bc.htm'},
#  {'category': 'Space & Time', 'url': 'st.htm'},
#  {'category': 'Forces & Motion', 'url': 'fm.htm'},
#  {'category': 'Matter & Nature', 'url': 'mn.htm'},
#  {'category': 'Life & Humans', 'url': 'lh.htm'},
#  {'category': 'Perception & Cognition', 'url': 'pc.htm'},
#  {'category': 'Meaning & Spirit', 'url': 'ms.htm'},
#  {'category': 'Character & Emotions', 'url': 'ce.htm'},
#  {'category': 'Action & Modality', 'url': 'am.htm'},
#  {'category': 'Attitudes', 'url': 'at.htm'},
#  {'category': 'Communauty', 'url': 'cm.htm'},
#  {'category': 'Conflict & Justice', 'url': 'cj.htm'},
#  {'category': 'Work & Possession', 'url': 'wp.htm'},
#  {'category': 'Daily Life (I)', 'url': 'd1.htm'},
#  {'category': 'Daily Life (II)', 'url': 'd2.htm'},
#  {'category': 'Locutions', 'url': 'lo.htm'},
#  {'category': 'Proper Names', 'url': 'pn.htm'}]

# %%
pd.Series([td.attrs['class'][0] for h2 in soup.find_all('h2') 
                      for td in h2.find_next_sibling('table').find_all('td')]).value_counts()
# Out:
# mid           2215
# top           1011
# bot            849
# mono           807
# out            620
# top_ex         277
# bot_ex         196
# bot_bot_ex      81
# mid_ex_t        76
# mid_ex_s        76
# mono_mid        14
# mono_left       14
# mono_right      14
# dtype: int64

# %%
def extractCardsFromUrl(cat_url = 'ms.htm'):
    with urllib.request.urlopen(home_url + cat_url) as response:
        html = response.read()
    cat_soup = BeautifulSoup(html, 'html.parser')

    cards = []
    current_card = {}
    in_example = False
    example_text = []

    for h2 in cat_soup.find_all('h2'):
        #print(h2.text)
        for tr in h2.find_next_sibling('table').find_all('tr'):
            for i, td in enumerate(tr.find_all('td')):
                # item name in column 0
                if i == 0:
                    if td.text.strip():
                        #print('ITEM', td.text)
                        item_attributes = {'item': td.text.strip(), 
                                           'item_bold': bool(td.b), 
                                           'domain': h2.text.strip()}

                # desc (and example!) in column 1
                if i == 1:
                    if td.attrs['class'][0] == 'top_ex':
                        in_example = True
                        example_text = []

                    if in_example:
                        #print('EXAMPLE', td.text)
                        example_text.append(td.text.strip())
                    else:
                        if td.text.strip():
                            if 'item' in current_card:
                                cards.append(current_card)
                            #print('DESC', td.text)
                            current_card = item_attributes.copy()
                            current_card['desc'] = td.text.strip()
                            current_card['desc_bold'] = bool(td.b)
                            current_card['meaning'] = []

                    if td.attrs['class'][0] in ['bot_ex', 'bot_bot_ex']:
                        in_example = False
                        current_card['example'] = example_text

                # meaning in column 2
                if i == 2:
                    if td.text.strip():
                        current_card['meaning'].append(td.text.strip())

    result = pd.DataFrame(cards)
    result['url'] = cat_url
    
    return result

# %%
pagesCards = []

for page in cat_url_map[:-2]:
    print(page['category'])
    pagesCards.append(extractCardsFromUrl(page['url']))
    
AllCards = pd.concat(pagesCards).reset_index(drop=True)
# Out:
# Basic Concepts
# Space & Time
# Forces & Motion
# Matter & Nature
# Life & Humans
# Perception & Cognition
# Meaning & Spirit
# Character & Emotions
# Action & Modality
# Attitudes
# Communauty
# Conflict & Justice
# Work & Possession
# Daily Life (I)
# Daily Life (II)

# %%
AllCards[AllCards.desc_bold].sample(20)
# Out:
#                  item  item_bold                       domain  \
# 4291         yaralan-       True          Health and Medicine
# 10255            ODAT       True                      Society
# 12581            QUTI       True            Objects and Tools
# 2270           kuchli       True           Forces and Effects
# 3390          TURMUSH       True              Vital Functions
# 8083   O'RIN (o'rn+i)       True             Acts and Results
# 7522             ORZU       True  Will, Ability and Necessity
# 1730          TO'XTA-       True         Events and Evolution
# 9726            KELIN       True                       Family
# 207             MISOL       True                    Relations
# 6097               OT       True                      Meaning
# 5648            USTUN       True                      Opinion
# 11175     GADO/ GADOY       True      Possession and Exchange
# 10003       tabrikla-       True                  Social Life
# 7737           MUHTOJ       True  Will, Ability and Necessity
# 10131         ommabop       True                      Society
# 9854          QO'SHNI       True                  Social Life
# 13589          KO'CHA       True                    Transport
# 7864             BOQ-       True             Acts and Results
# 5288          LEKSIYA       True                    Knowledge
#
#                          desc  desc_bold  \
# 4291                    v.int       True
# 10255                       n       True
# 12581                       n       True
# 2270                      adj       True
# 3390                        n       True
# 8083         NX+ning o'rn+ida       True
# 7522   n | N(ish)X haqidagi ~       True
# 1730                    v.int       True
# 9726                        n       True
# 207                         n       True
# 6097                        n       True
# 5648                      adj       True
# 11175                       n       True
# 10003  v.t | N(gani)X bilan ~       True
# 7737                      adj       True
# 10131                     adj       True
# 9854                        n       True
# 13589             shoh ko'cha       True
# 7864          v.int | VX+ib ~       True
# 5288                 n | NX ~       True
#
#                                             meaning  \
# 4291                                  [get wounded]
# 10255                        [habit, custom, usage]
# 12581                          [box, chest, drawer]
# 2270                             [strong, powerful]
# 3390                     [life (lived), livelihood]
# 8083                                 [in X's place]
# 7522   [desire, aspiration, hope, wish, dream of X]
# 1730               [stop, wait, stay, stop a while]
# 9726       [bride, daughter-in-law (son's husband)]
# 207                                       [example]
# 6097                           [(given) name, noun]
# 5648                                     [superior]
# 11175                                      [beggar]
# 10003          [congratulate on X, compliment on X]
# 7737                               [needy, in need]
# 10131                             [popular, common]
# 9854                                    [neighbour]
# 13589                         [avenue, main street]
# 7864                       [try to X, attempt to X]
# 5288                                 [lecture on X]
#
#                                                  example     url
# 4291                                                 NaN  lh.htm
# 10255                                                NaN  cm.htm
# 12581       [Bir quti papiros., A packet of cigarettes.]  d1.htm
# 2270                                                 NaN  fm.htm
# 3390      [Turmushim yomon emas., I am not doing badly.]  lh.htm
# 8083                                                 NaN  am.htm
# 7522   [Baxtli oilaviy hayot haqidagi orzu uning xayo...  am.htm
# 1730       [Bu yerda to'xtab turing!, Wait here please!]  st.htm
# 9726                                                 NaN  cm.htm
# 207    [Qilgan ishimiz uchun bu yaqqol misol bo'la ol...  bc.htm
# 6097                 [Otingiz nima?, What is your name?]  ms.htm
# 5648                                                 NaN  ms.htm
# 11175                                                NaN  wp.htm
# 10003                                                NaN  cm.htm
# 7737                                                 NaN  am.htm
# 10131                                                NaN  cm.htm
# 9854                                                 NaN  cm.htm
# 13589                                                NaN  d2.htm
# 7864   [Kitobingizni o'qib boqaychi!, Let me have a l...  am.htm
# 5288   [Biz matematika leksiyalariga jon-dilimiz bila...  pc.htm

# %%
AllCards.groupby('item')['url'].nunique().sort_values(ascending=False)[:50]
# Out:
# item
# O'T-              5
# KO'R-             5
# TUR-              5
# CHIQ-             5
# BOS-              5
# OL-               5
# BO'L-             5
# JON               4
# YUZ               4
# BALAND            4
# OG'IZ (og'z+i)    4
# TUSH-             4
# qaytar-           4
# KEL-              4
# TASHLA-           4
# OCH-              4
# o'chir-           4
# FARQ              4
# pishiq            4
# BUZ-              4
# YUT-              4
# BO'Y              4
# O'RIN (o'rn+i)    4
# TORT-             4
# KET-              4
# YAQIN             4
# ochil-            4
# YOZ-              4
# BOSH              4
# YOQ-              4
# TO'P              4
# TO'G'RI           4
# HAQ               4
# o'tkaz-           4
# BIL-              4
# ajral-            4
# ajrat-            4
# QOL-              4
# kelish-           4
# QARA-             4
# HISOB             4
# kutil-            4
# ko'chir-          4
# KUT-              4
# PAST              4
# KIR-              4
# BEKOR             3
# AYLAN-            3
# UZAT-             3
# TO'Q              3
# Name: url, dtype: int64
